# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale,Normalizer,OneHotEncoder
from sklearn.preprocessing import normalize
from keras.models import Sequential,load_model
from tensorflow.python.keras.saving.saved_model import load as saved_model_load
from keras.layers import Dense, Dropout, Flatten,BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
import keras.optimizers

# %%
train = pd.read_csv('task4.training.csv')

# %%
test = pd.read_csv('task4.test.WITHOUT.csv')

# %%
train_answer = train['class']

# %%
train['class']
# Out:
# 0       F
# 1       E
# 2       G
# 3       H
# 4       C
#        ..
# 9995    G
# 9996    A
# 9997    I
# 9998    B
# 9999    C
# Name: class, Length: 10000, dtype: object

# %%
train = train.drop(columns = 'class')

# %%
enc = OneHotEncoder(handle_unknown = 'ignore')
enc.fit(train['f24'])
train_feature = enc.transform(train['f24']).toarray()
test_feature = enc.transform(test['f24']).toarray()

# %%
train = np.array(train,dtype=np.float32)
test = np.array(test,dtype=np.float32)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-30c041554e36> in <module>
# ----> 1 train = np.array(train,dtype=np.float32)
#       2 test = np.array(test,dtype=np.float32)
#
# ValueError: could not convert string to float: 'G'

# %%
meanlist=[]
stdlist =[]

# %%
for i in range(np.shape(train)[1]):
    tmp = np.sum(train[:,i])
    mean = tmp/np.shape(train)[0]
    meanlist.append(mean)
    std = np.std(train[:,i])
    stdlist.append(std)
    for j in range(np.shape(train)[0]):
        train[j][i] = (train[j][i]-mean)/std

# %%
meanlist
# Out:
# [14.11098125,
#  10.29418125,
#  14.5605890625,
#  10.60308359375,
#  10.64488828125,
#  2.5184447265625,
#  3.743784375,
#  13.9763234375,
#  10.3168421875,
#  14.5071,
#  -4.08537109375,
#  -0.623285498046875,
#  4.92981484375,
#  1.50235380859375,
#  -1.0974939453125,
#  3.89726171875,
#  -3.834880859375,
#  -9.4037734375,
#  6.48721328125,
#  -3.663765625,
#  -11.5912203125,
#  8.475678125,
#  1.974383203125]

# %%
stdlist
# Out:
# [7.0262885,
#  2.9842222,
#  5.274214,
#  5.0233293,
#  5.038989,
#  1.0358857,
#  1.5579286,
#  6.9281745,
#  2.9644775,
#  5.262559,
#  8.823478,
#  6.2141843,
#  5.3735723,
#  0.87075037,
#  3.813243,
#  3.8114076,
#  11.023049,
#  8.246449,
#  7.4918504,
#  8.757567,
#  7.206334,
#  9.750384,
#  7.441513]

# %%
# normalizer = Normalizer().fit(train) 
# train = normalizer.transform(train)

# %%
np.shape(train[:,1])
# Out:
# (10000,)

# %%
ans = pd.get_dummies(train_answer)

# %%
ans = np.array(ans)

# %%
train_feature_len = np.shape(train)[1]

# %%
train_x,val_x,train_y,val_y = train_test_split(train,ans,test_size=0.3,random_state=44)

# %%
np.shape(train_x)
# Out:
# (7000, 23)

# %%
from keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
lr= 1e-2
opti =keras.optimizers.Adam(learning_rate=lr)
model3 = Sequential()  
model3.add(Dense(train_feature_len*1, activation = 'relu',use_bias=True))
#model3.add(BatchNormalization())
model3.add(Dense(train_feature_len*2, activation = 'relu',use_bias=True))
#model3.add(BatchNormalization())
model3.add(Dense(train_feature_len*3, activation = 'relu',use_bias=True))
#model3.add(BatchNormalization())
model3.add(Dense(train_feature_len*3, activation = 'relu',use_bias=True))
#model3.add(BatchNormalization())
model3.add(Dense(train_feature_len*1, activation = 'relu',use_bias=True))
#model3.add(BatchNormalization())
model3.add(Dense(10, activation = 'softmax',use_bias=True))
para3 = model3.compile(optimizer = opti, loss = 'categorical_crossentropy', metrics = ['acc',f1_m,precision_m, recall_m])

# %%
# model3=load_model('ML_task2.h5')

# %%
# checkpoint
filepath="weights_with_normalize.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True,
mode='max')
callbacks_list = [checkpoint]

# %%
#model3 = load_model('weights.best.hdf5',custom_objects={'f1_m':f1_m,'precision_m':precision_m,'recall_m':recall_m})
# model3 = load_model('weights_with_normalize.best.hdf5',custom_objects={'f1_m':f1_m,'precision_m':precision_m,'recall_m':recall_m})

# %%
print('Training ------------')
model3.fit(train_x, train_y, validation_split=0.33, epochs=1500,batch_size=128,callbacks=callbacks_list,verbose=0) #2000
# Out:
# Training ------------
#
# Epoch 00001: val_acc did not improve from 0.95154
#
# Epoch 00002: val_acc did not improve from 0.95154
#
# Epoch 00003: val_acc did not improve from 0.95154
#
# Epoch 00004: val_acc did not improve from 0.95154
#
# Epoch 00005: val_acc did not improve from 0.95154
#
# Epoch 00006: val_acc did not improve from 0.95154
#
# Epoch 00007: val_acc did not improve from 0.95154
#
# Epoch 00008: val_acc did not improve from 0.95154
#
# Epoch 00009: val_acc did not improve from 0.95154
#
# Epoch 00010: val_acc did not improve from 0.95154
#
# Epoch 00011: val_acc did not improve from 0.95154
#
# Epoch 00012: val_acc did not improve from 0.95154
#
# Epoch 00013: val_acc did not improve from 0.95154
#
# Epoch 00014: val_acc did not improve from 0.95154
#
# Epoch 00015: val_acc did not improve from 0.95154
#
# Epoch 00016: val_acc did not improve from 0.95154
#
# Epoch 00017: val_acc did not improve from 0.95154
#
# Epoch 00018: val_acc did not improve from 0.95154
#
# Epoch 00019: val_acc did not improve from 0.95154
#
# Epoch 00020: val_acc did not improve from 0.95154
#
# Epoch 00021: val_acc did not improve from 0.95154
#
# Epoch 00022: val_acc did not improve from 0.95154
#
# Epoch 00023: val_acc did not improve from 0.95154
#
# Epoch 00024: val_acc did not improve from 0.95154
#
# Epoch 00025: val_acc did not improve from 0.95154
#
# Epoch 00026: val_acc did not improve from 0.95154
#
# Epoch 00027: val_acc did not improve from 0.95154
#
# Epoch 00028: val_acc did not improve from 0.95154
#
# Epoch 00029: val_acc did not improve from 0.95154
#
# Epoch 00030: val_acc did not improve from 0.95154
#
# Epoch 00031: val_acc did not improve from 0.95154
#
# Epoch 00032: val_acc did not improve from 0.95154
#
# Epoch 00033: val_acc did not improve from 0.95154
#
# Epoch 00034: val_acc did not improve from 0.95154
#
# Epoch 00035: val_acc did not improve from 0.95154
#
# Epoch 00036: val_acc did not improve from 0.95154
#
# Epoch 00037: val_acc did not improve from 0.95154
#
# Epoch 00038: val_acc did not improve from 0.95154
#
# Epoch 00039: val_acc did not improve from 0.95154
#
# Epoch 00040: val_acc did not improve from 0.95154
#
# Epoch 00041: val_acc did not improve from 0.95154
#
# Epoch 00042: val_acc did not improve from 0.95154
#
# Epoch 00043: val_acc did not improve from 0.95154
#
# Epoch 00044: val_acc did not improve from 0.95154
#
# Epoch 00045: val_acc did not improve from 0.95154
#
# Epoch 00046: val_acc did not improve from 0.95154
#
# Epoch 00047: val_acc did not improve from 0.95154
#
# Epoch 00048: val_acc did not improve from 0.95154
#
# Epoch 00049: val_acc did not improve from 0.95154
#
# Epoch 00050: val_acc did not improve from 0.95154
#
# Epoch 00051: val_acc did not improve from 0.95154
#
# Epoch 00052: val_acc did not improve from 0.95154
#
# Epoch 00053: val_acc did not improve from 0.95154
#
# Epoch 00054: val_acc did not improve from 0.95154
#
# Epoch 00055: val_acc did not improve from 0.95154
#
# Epoch 00056: val_acc did not improve from 0.95154
#
# Epoch 00057: val_acc did not improve from 0.95154
#
# Epoch 00058: val_acc did not improve from 0.95154
#
# Epoch 00059: val_acc did not improve from 0.95154
#
# Epoch 00060: val_acc did not improve from 0.95154
#
# Epoch 00061: val_acc did not improve from 0.95154
#
# Epoch 00062: val_acc did not improve from 0.95154
#
# Epoch 00063: val_acc did not improve from 0.95154
#
# Epoch 00064: val_acc did not improve from 0.95154
#
# Epoch 00065: val_acc did not improve from 0.95154
#
# Epoch 00066: val_acc did not improve from 0.95154
#
# Epoch 00067: val_acc did not improve from 0.95154
#
# Epoch 00068: val_acc did not improve from 0.95154
#
# Epoch 00069: val_acc did not improve from 0.95154
#
# Epoch 00070: val_acc did not improve from 0.95154
#
# Epoch 00071: val_acc did not improve from 0.95154
#
# Epoch 00072: val_acc did not improve from 0.95154
#
# Epoch 00073: val_acc did not improve from 0.95154
#
# Epoch 00074: val_acc did not improve from 0.95154
#
# Epoch 00075: val_acc did not improve from 0.95154
#
# Epoch 00076: val_acc did not improve from 0.95154
#
# Epoch 00077: val_acc did not improve from 0.95154
#
# Epoch 00078: val_acc did not improve from 0.95154
#
# Epoch 00079: val_acc did not improve from 0.95154
#
# Epoch 00080: val_acc did not improve from 0.95154
#
# Epoch 00081: val_acc did not improve from 0.95154
#
# Epoch 00082: val_acc did not improve from 0.95154
#
# Epoch 00083: val_acc did not improve from 0.95154
#
# Epoch 00084: val_acc did not improve from 0.95154
#
# Epoch 00085: val_acc did not improve from 0.95154
#
# Epoch 00086: val_acc did not improve from 0.95154
#
# Epoch 00087: val_acc did not improve from 0.95154
#
# Epoch 00088: val_acc did not improve from 0.95154
#
# Epoch 00089: val_acc did not improve from 0.95154
#
# Epoch 00090: val_acc did not improve from 0.95154
#
# Epoch 00091: val_acc did not improve from 0.95154
#
# Epoch 00092: val_acc did not improve from 0.95154
#
# Epoch 00093: val_acc did not improve from 0.95154
#
# Epoch 00094: val_acc did not improve from 0.95154
#
# Epoch 00095: val_acc did not improve from 0.95154
#
# Epoch 00096: val_acc did not improve from 0.95154
#
# Epoch 00097: val_acc did not improve from 0.95154
#
# Epoch 00098: val_acc did not improve from 0.95154
#
# Epoch 00099: val_acc did not improve from 0.95154
#
# Epoch 00100: val_acc did not improve from 0.95154
#
# Epoch 00101: val_acc did not improve from 0.95154
#
# Epoch 00102: val_acc did not improve from 0.95154
#
# Epoch 00103: val_acc did not improve from 0.95154
#
# Epoch 00104: val_acc did not improve from 0.95154
#
# Epoch 00105: val_acc did not improve from 0.95154
#
# Epoch 00106: val_acc did not improve from 0.95154
#
# Epoch 00107: val_acc did not improve from 0.95154
#
# Epoch 00108: val_acc did not improve from 0.95154
#
# Epoch 00109: val_acc did not improve from 0.95154
#
# Epoch 00110: val_acc did not improve from 0.95154
#
# Epoch 00111: val_acc did not improve from 0.95154
#
# Epoch 00112: val_acc did not improve from 0.95154
#
# Epoch 00113: val_acc did not improve from 0.95154
#
# Epoch 00114: val_acc did not improve from 0.95154
#
# Epoch 00115: val_acc did not improve from 0.95154
#
# Epoch 00116: val_acc did not improve from 0.95154
#
# Epoch 00117: val_acc did not improve from 0.95154
#
# Epoch 00118: val_acc did not improve from 0.95154
#
# Epoch 00119: val_acc did not improve from 0.95154
#
# Epoch 00120: val_acc did not improve from 0.95154
#
# Epoch 00121: val_acc did not improve from 0.95154
#
# Epoch 00122: val_acc did not improve from 0.95154
#
# Epoch 00123: val_acc did not improve from 0.95154
#
# Epoch 00124: val_acc did not improve from 0.95154
#
# Epoch 00125: val_acc did not improve from 0.95154
#
# Epoch 00126: val_acc did not improve from 0.95154
#
# Epoch 00127: val_acc did not improve from 0.95154
#
# Epoch 00128: val_acc did not improve from 0.95154
#
# Epoch 00129: val_acc did not improve from 0.95154
#
# Epoch 00130: val_acc did not improve from 0.95154
#
# Epoch 00131: val_acc did not improve from 0.95154
#
# Epoch 00132: val_acc did not improve from 0.95154
#
# Epoch 00133: val_acc did not improve from 0.95154
#
# Epoch 00134: val_acc did not improve from 0.95154
#
# Epoch 00135: val_acc did not improve from 0.95154
#
# Epoch 00136: val_acc did not improve from 0.95154
#
# Epoch 00137: val_acc did not improve from 0.95154
#
# Epoch 00138: val_acc did not improve from 0.95154
#
# Epoch 00139: val_acc did not improve from 0.95154
#
# Epoch 00140: val_acc did not improve from 0.95154
#
# Epoch 00141: val_acc did not improve from 0.95154
#
# Epoch 00142: val_acc did not improve from 0.95154
#
# Epoch 00143: val_acc did not improve from 0.95154
#
# Epoch 00144: val_acc did not improve from 0.95154
#
# Epoch 00145: val_acc did not improve from 0.95154
#
# Epoch 00146: val_acc did not improve from 0.95154
#
# Epoch 00147: val_acc did not improve from 0.95154
#
# Epoch 00148: val_acc did not improve from 0.95154
#
# Epoch 00149: val_acc did not improve from 0.95154
#
# Epoch 00150: val_acc did not improve from 0.95154
#
# Epoch 00151: val_acc did not improve from 0.95154
#
# Epoch 00152: val_acc did not improve from 0.95154
#
# Epoch 00153: val_acc did not improve from 0.95154
#
# Epoch 00154: val_acc did not improve from 0.95154
#
# Epoch 00155: val_acc did not improve from 0.95154
#
# Epoch 00156: val_acc did not improve from 0.95154
#
# Epoch 00157: val_acc did not improve from 0.95154
#
# Epoch 00158: val_acc did not improve from 0.95154
#
# Epoch 00159: val_acc did not improve from 0.95154
#
# Epoch 00160: val_acc did not improve from 0.95154
#
# Epoch 00161: val_acc did not improve from 0.95154
#
# Epoch 00162: val_acc did not improve from 0.95154
#
# Epoch 00163: val_acc did not improve from 0.95154
#
# Epoch 00164: val_acc did not improve from 0.95154
#
# Epoch 00165: val_acc did not improve from 0.95154
#
# Epoch 00166: val_acc did not improve from 0.95154
#
# Epoch 00167: val_acc did not improve from 0.95154
#
# Epoch 00168: val_acc did not improve from 0.95154
#
# Epoch 00169: val_acc did not improve from 0.95154
#
# Epoch 00170: val_acc did not improve from 0.95154
#
# Epoch 00171: val_acc did not improve from 0.95154
#
# Epoch 00172: val_acc did not improve from 0.95154
#
# Epoch 00173: val_acc did not improve from 0.95154
#
# Epoch 00174: val_acc did not improve from 0.95154
#
# Epoch 00175: val_acc did not improve from 0.95154
#
# Epoch 00176: val_acc did not improve from 0.95154
#
# Epoch 00177: val_acc did not improve from 0.95154
#
# Epoch 00178: val_acc did not improve from 0.95154
#
# Epoch 00179: val_acc did not improve from 0.95154
#
# Epoch 00180: val_acc did not improve from 0.95154
#
# Epoch 00181: val_acc did not improve from 0.95154
#
# Epoch 00182: val_acc did not improve from 0.95154
#
# Epoch 00183: val_acc did not improve from 0.95154
#
# Epoch 00184: val_acc did not improve from 0.95154
#
# Epoch 00185: val_acc did not improve from 0.95154
#
# Epoch 00186: val_acc did not improve from 0.95154
#
# Epoch 00187: val_acc did not improve from 0.95154
#
# Epoch 00188: val_acc did not improve from 0.95154
#
# Epoch 00189: val_acc did not improve from 0.95154
#
# Epoch 00190: val_acc did not improve from 0.95154
#
# Epoch 00191: val_acc did not improve from 0.95154
#
# Epoch 00192: val_acc did not improve from 0.95154
#
# Epoch 00193: val_acc did not improve from 0.95154
#
# Epoch 00194: val_acc did not improve from 0.95154
#
# Epoch 00195: val_acc did not improve from 0.95154
#
# Epoch 00196: val_acc did not improve from 0.95154
#
# Epoch 00197: val_acc did not improve from 0.95154
#
# Epoch 00198: val_acc did not improve from 0.95154
#
# Epoch 00199: val_acc did not improve from 0.95154
#
# Epoch 00200: val_acc did not improve from 0.95154
#
# Epoch 00201: val_acc did not improve from 0.95154
#
# Epoch 00202: val_acc did not improve from 0.95154
#
# Epoch 00203: val_acc did not improve from 0.95154
#
# Epoch 00204: val_acc did not improve from 0.95154
#
# Epoch 00205: val_acc did not improve from 0.95154
#
# Epoch 00206: val_acc did not improve from 0.95154
#
# Epoch 00207: val_acc did not improve from 0.95154
#
# Epoch 00208: val_acc did not improve from 0.95154
#
# Epoch 00209: val_acc did not improve from 0.95154
#
# Epoch 00210: val_acc did not improve from 0.95154
#
# Epoch 00211: val_acc did not improve from 0.95154
#
# Epoch 00212: val_acc did not improve from 0.95154
#
# Epoch 00213: val_acc did not improve from 0.95154
#
# Epoch 00214: val_acc did not improve from 0.95154
#
# Epoch 00215: val_acc did not improve from 0.95154
#
# Epoch 00216: val_acc did not improve from 0.95154
#
# Epoch 00217: val_acc did not improve from 0.95154
#
# Epoch 00218: val_acc did not improve from 0.95154
#
# Epoch 00219: val_acc did not improve from 0.95154
#
# Epoch 00220: val_acc did not improve from 0.95154
#
# Epoch 00221: val_acc did not improve from 0.95154
#
# Epoch 00222: val_acc did not improve from 0.95154
#
# Epoch 00223: val_acc did not improve from 0.95154
#
# Epoch 00224: val_acc did not improve from 0.95154
#
# Epoch 00225: val_acc did not improve from 0.95154
#
# Epoch 00226: val_acc did not improve from 0.95154
#
# Epoch 00227: val_acc did not improve from 0.95154
#
# Epoch 00228: val_acc did not improve from 0.95154
#
# Epoch 00229: val_acc did not improve from 0.95154
#
# Epoch 00230: val_acc did not improve from 0.95154
#
# Epoch 00231: val_acc did not improve from 0.95154
#
# Epoch 00232: val_acc did not improve from 0.95154
#
# Epoch 00233: val_acc did not improve from 0.95154
#
# Epoch 00234: val_acc did not improve from 0.95154
#
# Epoch 00235: val_acc did not improve from 0.95154
#
# Epoch 00236: val_acc did not improve from 0.95154
#
# Epoch 00237: val_acc did not improve from 0.95154
#
# Epoch 00238: val_acc did not improve from 0.95154
#
# Epoch 00239: val_acc did not improve from 0.95154
#
# Epoch 00240: val_acc did not improve from 0.95154
#
# Epoch 00241: val_acc did not improve from 0.95154
#
# Epoch 00242: val_acc did not improve from 0.95154
#
# Epoch 00243: val_acc did not improve from 0.95154
#
# Epoch 00244: val_acc did not improve from 0.95154
#
# Epoch 00245: val_acc did not improve from 0.95154
#
# Epoch 00246: val_acc did not improve from 0.95154
#
# Epoch 00247: val_acc did not improve from 0.95154
#
# Epoch 00248: val_acc did not improve from 0.95154
#
# Epoch 00249: val_acc did not improve from 0.95154
#
# Epoch 00250: val_acc did not improve from 0.95154
#
# Epoch 00251: val_acc did not improve from 0.95154
#
# Epoch 00252: val_acc did not improve from 0.95154
#
# Epoch 00253: val_acc did not improve from 0.95154
#
# Epoch 00254: val_acc did not improve from 0.95154
#
# Epoch 00255: val_acc did not improve from 0.95154
#
# Epoch 00256: val_acc did not improve from 0.95154
#
# Epoch 00257: val_acc did not improve from 0.95154
#
# Epoch 00258: val_acc did not improve from 0.95154
#
# Epoch 00259: val_acc did not improve from 0.95154
#
# Epoch 00260: val_acc did not improve from 0.95154
#
# Epoch 00261: val_acc did not improve from 0.95154
#
# Epoch 00262: val_acc did not improve from 0.95154
#
# Epoch 00263: val_acc did not improve from 0.95154
#
# Epoch 00264: val_acc did not improve from 0.95154
#
# Epoch 00265: val_acc did not improve from 0.95154
#
# Epoch 00266: val_acc did not improve from 0.95154
#
# Epoch 00267: val_acc did not improve from 0.95154
#
# Epoch 00268: val_acc did not improve from 0.95154
#
# Epoch 00269: val_acc did not improve from 0.95154
#
# Epoch 00270: val_acc did not improve from 0.95154
#
# Epoch 00271: val_acc did not improve from 0.95154
#
# Epoch 00272: val_acc did not improve from 0.95154
#
# Epoch 00273: val_acc did not improve from 0.95154
#
# Epoch 00274: val_acc did not improve from 0.95154
#
# Epoch 00275: val_acc did not improve from 0.95154
#
# Epoch 00276: val_acc did not improve from 0.95154
#
# Epoch 00277: val_acc did not improve from 0.95154
#
# Epoch 00278: val_acc did not improve from 0.95154
#
# Epoch 00279: val_acc did not improve from 0.95154
#
# Epoch 00280: val_acc did not improve from 0.95154
#
# Epoch 00281: val_acc did not improve from 0.95154
#
# Epoch 00282: val_acc did not improve from 0.95154
#
# Epoch 00283: val_acc did not improve from 0.95154
#
# Epoch 00284: val_acc did not improve from 0.95154
#
# Epoch 00285: val_acc did not improve from 0.95154
#
# Epoch 00286: val_acc did not improve from 0.95154
#
# Epoch 00287: val_acc did not improve from 0.95154
#
# Epoch 00288: val_acc did not improve from 0.95154
#
# Epoch 00289: val_acc did not improve from 0.95154
#
# Epoch 00290: val_acc did not improve from 0.95154
#
# Epoch 00291: val_acc did not improve from 0.95154
#
# Epoch 00292: val_acc did not improve from 0.95154
#
# Epoch 00293: val_acc did not improve from 0.95154
#
# Epoch 00294: val_acc did not improve from 0.95154
#
# Epoch 00295: val_acc did not improve from 0.95154
#
# Epoch 00296: val_acc did not improve from 0.95154
#
# Epoch 00297: val_acc did not improve from 0.95154
#
# Epoch 00298: val_acc did not improve from 0.95154
#
# Epoch 00299: val_acc did not improve from 0.95154
#
# Epoch 00300: val_acc did not improve from 0.95154
#
# Epoch 00301: val_acc did not improve from 0.95154
#
# Epoch 00302: val_acc did not improve from 0.95154
#
# Epoch 00303: val_acc did not improve from 0.95154
#
# Epoch 00304: val_acc did not improve from 0.95154
#
# Epoch 00305: val_acc did not improve from 0.95154
#
# Epoch 00306: val_acc did not improve from 0.95154
#
# Epoch 00307: val_acc did not improve from 0.95154
#
# Epoch 00308: val_acc did not improve from 0.95154
#
# Epoch 00309: val_acc did not improve from 0.95154
#
# Epoch 00310: val_acc did not improve from 0.95154
#
# Epoch 00311: val_acc did not improve from 0.95154
#
# Epoch 00312: val_acc did not improve from 0.95154
#
# Epoch 00313: val_acc did not improve from 0.95154
#
# Epoch 00314: val_acc did not improve from 0.95154
#
# Epoch 00315: val_acc did not improve from 0.95154
#
# Epoch 00316: val_acc did not improve from 0.95154
#
# Epoch 00317: val_acc did not improve from 0.95154
#
# Epoch 00318: val_acc did not improve from 0.95154
#
# Epoch 00319: val_acc did not improve from 0.95154
#
# Epoch 00320: val_acc did not improve from 0.95154
#
# Epoch 00321: val_acc did not improve from 0.95154
#
# Epoch 00322: val_acc did not improve from 0.95154
#
# Epoch 00323: val_acc did not improve from 0.95154
#
# Epoch 00324: val_acc did not improve from 0.95154
#
# Epoch 00325: val_acc did not improve from 0.95154
#
# Epoch 00326: val_acc did not improve from 0.95154
#
# Epoch 00327: val_acc did not improve from 0.95154
#
# Epoch 00328: val_acc did not improve from 0.95154
#
# Epoch 00329: val_acc did not improve from 0.95154
#
# Epoch 00330: val_acc did not improve from 0.95154
#
# Epoch 00331: val_acc did not improve from 0.95154
#
# Epoch 00332: val_acc did not improve from 0.95154
#
# Epoch 00333: val_acc did not improve from 0.95154
#
# Epoch 00334: val_acc did not improve from 0.95154
#
# Epoch 00335: val_acc did not improve from 0.95154
#
# Epoch 00336: val_acc did not improve from 0.95154
#
# Epoch 00337: val_acc did not improve from 0.95154
#
# Epoch 00338: val_acc did not improve from 0.95154
#
# Epoch 00339: val_acc did not improve from 0.95154
#
# Epoch 00340: val_acc did not improve from 0.95154
#
# Epoch 00341: val_acc did not improve from 0.95154
#
# Epoch 00342: val_acc did not improve from 0.95154
#
# Epoch 00343: val_acc did not improve from 0.95154
#
# Epoch 00344: val_acc did not improve from 0.95154
#
# Epoch 00345: val_acc did not improve from 0.95154
#
# Epoch 00346: val_acc did not improve from 0.95154
#
# Epoch 00347: val_acc did not improve from 0.95154
#
# Epoch 00348: val_acc did not improve from 0.95154
#
# Epoch 00349: val_acc did not improve from 0.95154
#
# Epoch 00350: val_acc did not improve from 0.95154
#
# Epoch 00351: val_acc did not improve from 0.95154
#
# Epoch 00352: val_acc did not improve from 0.95154
#
# Epoch 00353: val_acc did not improve from 0.95154
#
# Epoch 00354: val_acc did not improve from 0.95154
#
# Epoch 00355: val_acc did not improve from 0.95154
#
# Epoch 00356: val_acc did not improve from 0.95154
#
# Epoch 00357: val_acc did not improve from 0.95154
#
# Epoch 00358: val_acc did not improve from 0.95154
#
# Epoch 00359: val_acc did not improve from 0.95154
#
# Epoch 00360: val_acc did not improve from 0.95154
#
# Epoch 00361: val_acc did not improve from 0.95154
#
# Epoch 00362: val_acc did not improve from 0.95154
#
# Epoch 00363: val_acc did not improve from 0.95154
#
# Epoch 00364: val_acc did not improve from 0.95154
#
# Epoch 00365: val_acc did not improve from 0.95154
#
# Epoch 00366: val_acc did not improve from 0.95154
#
# Epoch 00367: val_acc did not improve from 0.95154
#
# Epoch 00368: val_acc did not improve from 0.95154
#
# Epoch 00369: val_acc did not improve from 0.95154
#
# Epoch 00370: val_acc did not improve from 0.95154
#
# Epoch 00371: val_acc did not improve from 0.95154
#
# Epoch 00372: val_acc did not improve from 0.95154
#
# Epoch 00373: val_acc did not improve from 0.95154
#
# Epoch 00374: val_acc did not improve from 0.95154
#
# Epoch 00375: val_acc did not improve from 0.95154
#
# Epoch 00376: val_acc did not improve from 0.95154
#
# Epoch 00377: val_acc did not improve from 0.95154
#
# Epoch 00378: val_acc did not improve from 0.95154
#
# Epoch 00379: val_acc did not improve from 0.95154
#
# Epoch 00380: val_acc did not improve from 0.95154
#
# Epoch 00381: val_acc did not improve from 0.95154
#
# Epoch 00382: val_acc did not improve from 0.95154
#
# Epoch 00383: val_acc did not improve from 0.95154
#
# Epoch 00384: val_acc did not improve from 0.95154
#
# Epoch 00385: val_acc did not improve from 0.95154
#
# Epoch 00386: val_acc did not improve from 0.95154
#
# Epoch 00387: val_acc did not improve from 0.95154
#
# Epoch 00388: val_acc did not improve from 0.95154
#
# Epoch 00389: val_acc did not improve from 0.95154
#
# Epoch 00390: val_acc did not improve from 0.95154
#
# Epoch 00391: val_acc did not improve from 0.95154
#
# Epoch 00392: val_acc did not improve from 0.95154
#
# Epoch 00393: val_acc did not improve from 0.95154
#
# Epoch 00394: val_acc did not improve from 0.95154
#
# Epoch 00395: val_acc did not improve from 0.95154
#
# Epoch 00396: val_acc did not improve from 0.95154
#
# Epoch 00397: val_acc did not improve from 0.95154
#
# Epoch 00398: val_acc did not improve from 0.95154
#
# Epoch 00399: val_acc did not improve from 0.95154
#
# Epoch 00400: val_acc did not improve from 0.95154
#
# Epoch 00401: val_acc did not improve from 0.95154
#
# Epoch 00402: val_acc did not improve from 0.95154
#
# Epoch 00403: val_acc did not improve from 0.95154
#
# Epoch 00404: val_acc did not improve from 0.95154
#
# Epoch 00405: val_acc did not improve from 0.95154
#
# Epoch 00406: val_acc did not improve from 0.95154
#
# Epoch 00407: val_acc did not improve from 0.95154
#
# Epoch 00408: val_acc did not improve from 0.95154
#
# Epoch 00409: val_acc did not improve from 0.95154
#
# Epoch 00410: val_acc did not improve from 0.95154
#
# Epoch 00411: val_acc did not improve from 0.95154
#
# Epoch 00412: val_acc did not improve from 0.95154
#
# Epoch 00413: val_acc did not improve from 0.95154
#
# Epoch 00414: val_acc did not improve from 0.95154
#
# Epoch 00415: val_acc did not improve from 0.95154
#
# Epoch 00416: val_acc did not improve from 0.95154
#
# Epoch 00417: val_acc did not improve from 0.95154
#
# Epoch 00418: val_acc did not improve from 0.95154
#
# Epoch 00419: val_acc did not improve from 0.95154
#
# Epoch 00420: val_acc did not improve from 0.95154
#
# Epoch 00421: val_acc did not improve from 0.95154
#
# Epoch 00422: val_acc did not improve from 0.95154
#
# Epoch 00423: val_acc did not improve from 0.95154
#
# Epoch 00424: val_acc did not improve from 0.95154
#
# Epoch 00425: val_acc did not improve from 0.95154
#
# Epoch 00426: val_acc did not improve from 0.95154
#
# Epoch 00427: val_acc did not improve from 0.95154
#
# Epoch 00428: val_acc did not improve from 0.95154
#
# Epoch 00429: val_acc did not improve from 0.95154
#
# Epoch 00430: val_acc did not improve from 0.95154
#
# Epoch 00431: val_acc did not improve from 0.95154
#
# Epoch 00432: val_acc did not improve from 0.95154
#
# Epoch 00433: val_acc did not improve from 0.95154
#
# Epoch 00434: val_acc did not improve from 0.95154
#
# Epoch 00435: val_acc did not improve from 0.95154
#
# Epoch 00436: val_acc did not improve from 0.95154
#
# Epoch 00437: val_acc did not improve from 0.95154
#
# Epoch 00438: val_acc did not improve from 0.95154
#
# Epoch 00439: val_acc did not improve from 0.95154
#
# Epoch 00440: val_acc did not improve from 0.95154
#
# Epoch 00441: val_acc did not improve from 0.95154
#
# Epoch 00442: val_acc did not improve from 0.95154
#
# Epoch 00443: val_acc did not improve from 0.95154
#
# Epoch 00444: val_acc did not improve from 0.95154
#
# Epoch 00445: val_acc did not improve from 0.95154
#
# Epoch 00446: val_acc did not improve from 0.95154
#
# Epoch 00447: val_acc did not improve from 0.95154
#
# Epoch 00448: val_acc did not improve from 0.95154
#
# Epoch 00449: val_acc did not improve from 0.95154
#
# Epoch 00450: val_acc did not improve from 0.95154
#
# Epoch 00451: val_acc did not improve from 0.95154
#
# Epoch 00452: val_acc did not improve from 0.95154
#
# Epoch 00453: val_acc did not improve from 0.95154
#
# Epoch 00454: val_acc did not improve from 0.95154
#
# Epoch 00455: val_acc did not improve from 0.95154
#
# Epoch 00456: val_acc did not improve from 0.95154
#
# Epoch 00457: val_acc did not improve from 0.95154
#
# Epoch 00458: val_acc did not improve from 0.95154
#
# Epoch 00459: val_acc did not improve from 0.95154
#
# Epoch 00460: val_acc did not improve from 0.95154
#
# Epoch 00461: val_acc did not improve from 0.95154
#
# Epoch 00462: val_acc did not improve from 0.95154
#
# Epoch 00463: val_acc did not improve from 0.95154
#
# Epoch 00464: val_acc did not improve from 0.95154
#
# Epoch 00465: val_acc did not improve from 0.95154
#
# Epoch 00466: val_acc did not improve from 0.95154
#
# Epoch 00467: val_acc did not improve from 0.95154
#
# Epoch 00468: val_acc did not improve from 0.95154
#
# Epoch 00469: val_acc did not improve from 0.95154
#
# Epoch 00470: val_acc did not improve from 0.95154
#
# Epoch 00471: val_acc did not improve from 0.95154
#
# Epoch 00472: val_acc did not improve from 0.95154
#
# Epoch 00473: val_acc did not improve from 0.95154
#
# Epoch 00474: val_acc did not improve from 0.95154
#
# Epoch 00475: val_acc did not improve from 0.95154
#
# Epoch 00476: val_acc did not improve from 0.95154
#
# Epoch 00477: val_acc did not improve from 0.95154
#
# Epoch 00478: val_acc did not improve from 0.95154
#
# Epoch 00479: val_acc did not improve from 0.95154
#
# Epoch 00480: val_acc did not improve from 0.95154
#
# Epoch 00481: val_acc did not improve from 0.95154
#
# Epoch 00482: val_acc did not improve from 0.95154
#
# Epoch 00483: val_acc did not improve from 0.95154
#
# Epoch 00484: val_acc did not improve from 0.95154
#
# Epoch 00485: val_acc did not improve from 0.95154
#
# Epoch 00486: val_acc did not improve from 0.95154
#
# Epoch 00487: val_acc did not improve from 0.95154
#
# Epoch 00488: val_acc did not improve from 0.95154
#
# Epoch 00489: val_acc did not improve from 0.95154
#
# Epoch 00490: val_acc did not improve from 0.95154
#
# Epoch 00491: val_acc did not improve from 0.95154
#
# Epoch 00492: val_acc did not improve from 0.95154
#
# Epoch 00493: val_acc did not improve from 0.95154
#
# Epoch 00494: val_acc did not improve from 0.95154
#
# Epoch 00495: val_acc did not improve from 0.95154
#
# Epoch 00496: val_acc did not improve from 0.95154
#
# Epoch 00497: val_acc did not improve from 0.95154
#
# Epoch 00498: val_acc did not improve from 0.95154
#
# Epoch 00499: val_acc did not improve from 0.95154
#
# Epoch 00500: val_acc did not improve from 0.95154
#
# Epoch 00501: val_acc did not improve from 0.95154
#
# Epoch 00502: val_acc did not improve from 0.95154
#
# Epoch 00503: val_acc did not improve from 0.95154
#
# Epoch 00504: val_acc did not improve from 0.95154
#
# Epoch 00505: val_acc did not improve from 0.95154
#
# Epoch 00506: val_acc did not improve from 0.95154
#
# Epoch 00507: val_acc did not improve from 0.95154
#
# Epoch 00508: val_acc did not improve from 0.95154
#
# Epoch 00509: val_acc did not improve from 0.95154
#
# Epoch 00510: val_acc did not improve from 0.95154
#
# Epoch 00511: val_acc did not improve from 0.95154
#
# Epoch 00512: val_acc did not improve from 0.95154
#
# Epoch 00513: val_acc did not improve from 0.95154
#
# Epoch 00514: val_acc did not improve from 0.95154
#
# Epoch 00515: val_acc did not improve from 0.95154
#
# Epoch 00516: val_acc did not improve from 0.95154
#
# Epoch 00517: val_acc did not improve from 0.95154
#
# Epoch 00518: val_acc did not improve from 0.95154
#
# Epoch 00519: val_acc did not improve from 0.95154
#
# Epoch 00520: val_acc did not improve from 0.95154
#
# Epoch 00521: val_acc did not improve from 0.95154
#
# Epoch 00522: val_acc did not improve from 0.95154
#
# Epoch 00523: val_acc did not improve from 0.95154
#
# Epoch 00524: val_acc did not improve from 0.95154
#
# Epoch 00525: val_acc did not improve from 0.95154
#
# Epoch 00526: val_acc did not improve from 0.95154
#
# Epoch 00527: val_acc did not improve from 0.95154
#
# Epoch 00528: val_acc did not improve from 0.95154
#
# Epoch 00529: val_acc did not improve from 0.95154
#
# Epoch 00530: val_acc did not improve from 0.95154
#
# Epoch 00531: val_acc did not improve from 0.95154
#
# Epoch 00532: val_acc did not improve from 0.95154
#
# Epoch 00533: val_acc did not improve from 0.95154
#
# Epoch 00534: val_acc did not improve from 0.95154
#
# Epoch 00535: val_acc did not improve from 0.95154
#
# Epoch 00536: val_acc did not improve from 0.95154
#
# Epoch 00537: val_acc did not improve from 0.95154
#
# Epoch 00538: val_acc did not improve from 0.95154
#
# Epoch 00539: val_acc did not improve from 0.95154
#
# Epoch 00540: val_acc did not improve from 0.95154
#
# Epoch 00541: val_acc did not improve from 0.95154
#
# Epoch 00542: val_acc did not improve from 0.95154
#
# Epoch 00543: val_acc did not improve from 0.95154
#
# Epoch 00544: val_acc did not improve from 0.95154
#
# Epoch 00545: val_acc did not improve from 0.95154
#
# Epoch 00546: val_acc did not improve from 0.95154
#
# Epoch 00547: val_acc did not improve from 0.95154
#
# Epoch 00548: val_acc did not improve from 0.95154
#
# Epoch 00549: val_acc did not improve from 0.95154
#
# Epoch 00550: val_acc did not improve from 0.95154
#
# Epoch 00551: val_acc did not improve from 0.95154
#
# Epoch 00552: val_acc did not improve from 0.95154
#
# Epoch 00553: val_acc did not improve from 0.95154
#
# Epoch 00554: val_acc did not improve from 0.95154
#
# Epoch 00555: val_acc did not improve from 0.95154
#
# Epoch 00556: val_acc did not improve from 0.95154
#
# Epoch 00557: val_acc did not improve from 0.95154
#
# Epoch 00558: val_acc did not improve from 0.95154
#
# Epoch 00559: val_acc did not improve from 0.95154
#
# Epoch 00560: val_acc did not improve from 0.95154
#
# Epoch 00561: val_acc did not improve from 0.95154
#
# Epoch 00562: val_acc did not improve from 0.95154
#
# Epoch 00563: val_acc did not improve from 0.95154
#
# Epoch 00564: val_acc did not improve from 0.95154
#
# Epoch 00565: val_acc did not improve from 0.95154
#
# Epoch 00566: val_acc did not improve from 0.95154
#
# Epoch 00567: val_acc did not improve from 0.95154
#
# Epoch 00568: val_acc did not improve from 0.95154
#
# Epoch 00569: val_acc did not improve from 0.95154
#
# Epoch 00570: val_acc did not improve from 0.95154
#
# Epoch 00571: val_acc did not improve from 0.95154
#
# Epoch 00572: val_acc did not improve from 0.95154
#
# Epoch 00573: val_acc did not improve from 0.95154
#
# Epoch 00574: val_acc did not improve from 0.95154
#
# Epoch 00575: val_acc did not improve from 0.95154
#
# Epoch 00576: val_acc did not improve from 0.95154
#
# Epoch 00577: val_acc did not improve from 0.95154
#
# Epoch 00578: val_acc did not improve from 0.95154
#
# Epoch 00579: val_acc did not improve from 0.95154
#
# Epoch 00580: val_acc did not improve from 0.95154
#
# Epoch 00581: val_acc did not improve from 0.95154
#
# Epoch 00582: val_acc did not improve from 0.95154
#
# Epoch 00583: val_acc did not improve from 0.95154
#
# Epoch 00584: val_acc did not improve from 0.95154
#
# Epoch 00585: val_acc did not improve from 0.95154
#
# Epoch 00586: val_acc did not improve from 0.95154
#
# Epoch 00587: val_acc did not improve from 0.95154
#
# Epoch 00588: val_acc did not improve from 0.95154
#
# Epoch 00589: val_acc did not improve from 0.95154
#
# Epoch 00590: val_acc did not improve from 0.95154
#
# Epoch 00591: val_acc did not improve from 0.95154
#
# Epoch 00592: val_acc did not improve from 0.95154
#
# Epoch 00593: val_acc did not improve from 0.95154
#
# Epoch 00594: val_acc did not improve from 0.95154
#
# Epoch 00595: val_acc did not improve from 0.95154
#
# Epoch 00596: val_acc did not improve from 0.95154
#
# Epoch 00597: val_acc did not improve from 0.95154
#
# Epoch 00598: val_acc did not improve from 0.95154
#
# Epoch 00599: val_acc did not improve from 0.95154
#
# Epoch 00600: val_acc did not improve from 0.95154
#
# Epoch 00601: val_acc did not improve from 0.95154
#
# Epoch 00602: val_acc did not improve from 0.95154
#
# Epoch 00603: val_acc did not improve from 0.95154
#
# Epoch 00604: val_acc did not improve from 0.95154
#
# Epoch 00605: val_acc did not improve from 0.95154
#
# Epoch 00606: val_acc did not improve from 0.95154
#
# Epoch 00607: val_acc did not improve from 0.95154
#
# Epoch 00608: val_acc did not improve from 0.95154
#
# Epoch 00609: val_acc did not improve from 0.95154
#
# Epoch 00610: val_acc did not improve from 0.95154
#
# Epoch 00611: val_acc did not improve from 0.95154
#
# Epoch 00612: val_acc did not improve from 0.95154
#
# Epoch 00613: val_acc did not improve from 0.95154
#
# Epoch 00614: val_acc did not improve from 0.95154
#
# Epoch 00615: val_acc did not improve from 0.95154
#
# Epoch 00616: val_acc did not improve from 0.95154
#
# Epoch 00617: val_acc did not improve from 0.95154
#
# Epoch 00618: val_acc did not improve from 0.95154
#
# Epoch 00619: val_acc did not improve from 0.95154
#
# Epoch 00620: val_acc did not improve from 0.95154
#
# Epoch 00621: val_acc did not improve from 0.95154
#
# Epoch 00622: val_acc did not improve from 0.95154
#
# Epoch 00623: val_acc did not improve from 0.95154
#
# Epoch 00624: val_acc did not improve from 0.95154
#
# Epoch 00625: val_acc did not improve from 0.95154
#
# Epoch 00626: val_acc did not improve from 0.95154
#
# Epoch 00627: val_acc did not improve from 0.95154
#
# Epoch 00628: val_acc did not improve from 0.95154
#
# Epoch 00629: val_acc did not improve from 0.95154
#
# Epoch 00630: val_acc did not improve from 0.95154
#
# Epoch 00631: val_acc did not improve from 0.95154
#
# Epoch 00632: val_acc did not improve from 0.95154
#
# Epoch 00633: val_acc did not improve from 0.95154
#
# Epoch 00634: val_acc did not improve from 0.95154
#
# Epoch 00635: val_acc did not improve from 0.95154
#
# Epoch 00636: val_acc did not improve from 0.95154
#
# Epoch 00637: val_acc did not improve from 0.95154
#
# Epoch 00638: val_acc did not improve from 0.95154
#
# Epoch 00639: val_acc did not improve from 0.95154
#
# Epoch 00640: val_acc did not improve from 0.95154
#
# Epoch 00641: val_acc did not improve from 0.95154
#
# Epoch 00642: val_acc did not improve from 0.95154
#
# Epoch 00643: val_acc did not improve from 0.95154
#
# Epoch 00644: val_acc did not improve from 0.95154
#
# Epoch 00645: val_acc did not improve from 0.95154
#
# Epoch 00646: val_acc did not improve from 0.95154
#
# Epoch 00647: val_acc did not improve from 0.95154
#
# Epoch 00648: val_acc did not improve from 0.95154
#
# Epoch 00649: val_acc did not improve from 0.95154
#
# Epoch 00650: val_acc did not improve from 0.95154
#
# Epoch 00651: val_acc did not improve from 0.95154
#
# Epoch 00652: val_acc did not improve from 0.95154
#
# Epoch 00653: val_acc did not improve from 0.95154
#
# Epoch 00654: val_acc did not improve from 0.95154
#
# Epoch 00655: val_acc did not improve from 0.95154
#
# Epoch 00656: val_acc did not improve from 0.95154
#
# Epoch 00657: val_acc did not improve from 0.95154
#
# Epoch 00658: val_acc did not improve from 0.95154
#
# Epoch 00659: val_acc did not improve from 0.95154
#
# Epoch 00660: val_acc did not improve from 0.95154
#
# Epoch 00661: val_acc did not improve from 0.95154
#
# Epoch 00662: val_acc did not improve from 0.95154
#
# Epoch 00663: val_acc did not improve from 0.95154
#
# Epoch 00664: val_acc did not improve from 0.95154
#
# Epoch 00665: val_acc did not improve from 0.95154
#
# Epoch 00666: val_acc did not improve from 0.95154
#
# Epoch 00667: val_acc did not improve from 0.95154
#
# Epoch 00668: val_acc did not improve from 0.95154
#
# Epoch 00669: val_acc did not improve from 0.95154
#
# Epoch 00670: val_acc did not improve from 0.95154
#
# Epoch 00671: val_acc did not improve from 0.95154
#
# Epoch 00672: val_acc did not improve from 0.95154
#
# Epoch 00673: val_acc did not improve from 0.95154
#
# Epoch 00674: val_acc did not improve from 0.95154
#
# Epoch 00675: val_acc did not improve from 0.95154
#
# Epoch 00676: val_acc did not improve from 0.95154
#
# Epoch 00677: val_acc did not improve from 0.95154
#
# Epoch 00678: val_acc did not improve from 0.95154
#
# Epoch 00679: val_acc did not improve from 0.95154
#
# Epoch 00680: val_acc did not improve from 0.95154
#
# Epoch 00681: val_acc did not improve from 0.95154
#
# Epoch 00682: val_acc did not improve from 0.95154
#
# Epoch 00683: val_acc did not improve from 0.95154
#
# Epoch 00684: val_acc did not improve from 0.95154
#
# Epoch 00685: val_acc did not improve from 0.95154
#
# Epoch 00686: val_acc did not improve from 0.95154
#
# Epoch 00687: val_acc did not improve from 0.95154
#
# Epoch 00688: val_acc did not improve from 0.95154
#
# Epoch 00689: val_acc did not improve from 0.95154
#
# Epoch 00690: val_acc did not improve from 0.95154
#
# Epoch 00691: val_acc did not improve from 0.95154
#
# Epoch 00692: val_acc did not improve from 0.95154
#
# Epoch 00693: val_acc did not improve from 0.95154
#
# Epoch 00694: val_acc did not improve from 0.95154
#
# Epoch 00695: val_acc did not improve from 0.95154
#
# Epoch 00696: val_acc did not improve from 0.95154
#
# Epoch 00697: val_acc did not improve from 0.95154
#
# Epoch 00698: val_acc did not improve from 0.95154
#
# Epoch 00699: val_acc did not improve from 0.95154
#
# Epoch 00700: val_acc did not improve from 0.95154
#
# Epoch 00701: val_acc did not improve from 0.95154
#
# Epoch 00702: val_acc did not improve from 0.95154
#
# Epoch 00703: val_acc did not improve from 0.95154
#
# Epoch 00704: val_acc did not improve from 0.95154
#
# Epoch 00705: val_acc did not improve from 0.95154
#
# Epoch 00706: val_acc did not improve from 0.95154
#
# Epoch 00707: val_acc did not improve from 0.95154
#
# Epoch 00708: val_acc did not improve from 0.95154
#
# Epoch 00709: val_acc did not improve from 0.95154
#
# Epoch 00710: val_acc did not improve from 0.95154
#
# Epoch 00711: val_acc did not improve from 0.95154
#
# Epoch 00712: val_acc did not improve from 0.95154
#
# Epoch 00713: val_acc did not improve from 0.95154
#
# Epoch 00714: val_acc did not improve from 0.95154
#
# Epoch 00715: val_acc did not improve from 0.95154
#
# Epoch 00716: val_acc did not improve from 0.95154
#
# Epoch 00717: val_acc did not improve from 0.95154
#
# Epoch 00718: val_acc did not improve from 0.95154
#
# Epoch 00719: val_acc did not improve from 0.95154
#
# Epoch 00720: val_acc did not improve from 0.95154
#
# Epoch 00721: val_acc did not improve from 0.95154
#
# Epoch 00722: val_acc did not improve from 0.95154
#
# Epoch 00723: val_acc did not improve from 0.95154
#
# Epoch 00724: val_acc did not improve from 0.95154
#
# Epoch 00725: val_acc did not improve from 0.95154
#
# Epoch 00726: val_acc did not improve from 0.95154
#
# Epoch 00727: val_acc did not improve from 0.95154
#
# Epoch 00728: val_acc did not improve from 0.95154
#
# Epoch 00729: val_acc did not improve from 0.95154
#
# Epoch 00730: val_acc did not improve from 0.95154
#
# Epoch 00731: val_acc did not improve from 0.95154
#
# Epoch 00732: val_acc did not improve from 0.95154
#
# Epoch 00733: val_acc did not improve from 0.95154
#
# Epoch 00734: val_acc did not improve from 0.95154
#
# Epoch 00735: val_acc did not improve from 0.95154
#
# Epoch 00736: val_acc did not improve from 0.95154
#
# Epoch 00737: val_acc did not improve from 0.95154
#
# Epoch 00738: val_acc did not improve from 0.95154
#
# Epoch 00739: val_acc did not improve from 0.95154
#
# Epoch 00740: val_acc did not improve from 0.95154
#
# Epoch 00741: val_acc did not improve from 0.95154
#
# Epoch 00742: val_acc did not improve from 0.95154
#
# Epoch 00743: val_acc did not improve from 0.95154
#
# Epoch 00744: val_acc did not improve from 0.95154
#
# Epoch 00745: val_acc did not improve from 0.95154
#
# Epoch 00746: val_acc did not improve from 0.95154
#
# Epoch 00747: val_acc did not improve from 0.95154
#
# Epoch 00748: val_acc did not improve from 0.95154
#
# Epoch 00749: val_acc did not improve from 0.95154
#
# Epoch 00750: val_acc did not improve from 0.95154
#
# Epoch 00751: val_acc did not improve from 0.95154
#
# Epoch 00752: val_acc did not improve from 0.95154
#
# Epoch 00753: val_acc did not improve from 0.95154
#
# Epoch 00754: val_acc did not improve from 0.95154
#
# Epoch 00755: val_acc did not improve from 0.95154
#
# Epoch 00756: val_acc did not improve from 0.95154
#
# Epoch 00757: val_acc did not improve from 0.95154
#
# Epoch 00758: val_acc did not improve from 0.95154
#
# Epoch 00759: val_acc did not improve from 0.95154
#
# Epoch 00760: val_acc did not improve from 0.95154
#
# Epoch 00761: val_acc did not improve from 0.95154
#
# Epoch 00762: val_acc did not improve from 0.95154
#
# Epoch 00763: val_acc did not improve from 0.95154
#
# Epoch 00764: val_acc did not improve from 0.95154
#
# Epoch 00765: val_acc did not improve from 0.95154
#
# Epoch 00766: val_acc did not improve from 0.95154
#
# Epoch 00767: val_acc did not improve from 0.95154
#
# Epoch 00768: val_acc did not improve from 0.95154
#
# Epoch 00769: val_acc did not improve from 0.95154
#
# Epoch 00770: val_acc did not improve from 0.95154
#
# Epoch 00771: val_acc did not improve from 0.95154
#
# Epoch 00772: val_acc did not improve from 0.95154
#
# Epoch 00773: val_acc did not improve from 0.95154
#
# Epoch 00774: val_acc did not improve from 0.95154
#
# Epoch 00775: val_acc did not improve from 0.95154
#
# Epoch 00776: val_acc did not improve from 0.95154
#
# Epoch 00777: val_acc did not improve from 0.95154
#
# Epoch 00778: val_acc did not improve from 0.95154
#
# Epoch 00779: val_acc did not improve from 0.95154
#
# Epoch 00780: val_acc did not improve from 0.95154
#
# Epoch 00781: val_acc did not improve from 0.95154
#
# Epoch 00782: val_acc did not improve from 0.95154
#
# Epoch 00783: val_acc did not improve from 0.95154
#
# Epoch 00784: val_acc did not improve from 0.95154
#
# Epoch 00785: val_acc did not improve from 0.95154
#
# Epoch 00786: val_acc did not improve from 0.95154
#
# Epoch 00787: val_acc did not improve from 0.95154
#
# Epoch 00788: val_acc did not improve from 0.95154
#
# Epoch 00789: val_acc did not improve from 0.95154
#
# Epoch 00790: val_acc did not improve from 0.95154
#
# Epoch 00791: val_acc did not improve from 0.95154
#
# Epoch 00792: val_acc did not improve from 0.95154
#
# Epoch 00793: val_acc did not improve from 0.95154
#
# Epoch 00794: val_acc did not improve from 0.95154
#
# Epoch 00795: val_acc did not improve from 0.95154
#
# Epoch 00796: val_acc did not improve from 0.95154
#
# Epoch 00797: val_acc did not improve from 0.95154
#
# Epoch 00798: val_acc did not improve from 0.95154
#
# Epoch 00799: val_acc did not improve from 0.95154
#
# Epoch 00800: val_acc did not improve from 0.95154
#
# Epoch 00801: val_acc did not improve from 0.95154
#
# Epoch 00802: val_acc did not improve from 0.95154
#
# Epoch 00803: val_acc did not improve from 0.95154
#
# Epoch 00804: val_acc did not improve from 0.95154
#
# Epoch 00805: val_acc did not improve from 0.95154
#
# Epoch 00806: val_acc did not improve from 0.95154
#
# Epoch 00807: val_acc did not improve from 0.95154
#
# Epoch 00808: val_acc did not improve from 0.95154
#
# Epoch 00809: val_acc did not improve from 0.95154
#
# Epoch 00810: val_acc did not improve from 0.95154
#
# Epoch 00811: val_acc did not improve from 0.95154
#
# Epoch 00812: val_acc did not improve from 0.95154
#
# Epoch 00813: val_acc did not improve from 0.95154
#
# Epoch 00814: val_acc did not improve from 0.95154
#
# Epoch 00815: val_acc did not improve from 0.95154
#
# Epoch 00816: val_acc did not improve from 0.95154
#
# Epoch 00817: val_acc did not improve from 0.95154
#
# Epoch 00818: val_acc did not improve from 0.95154
#
# Epoch 00819: val_acc did not improve from 0.95154
#
# Epoch 00820: val_acc did not improve from 0.95154
#
# Epoch 00821: val_acc did not improve from 0.95154
#
# Epoch 00822: val_acc did not improve from 0.95154
#
# Epoch 00823: val_acc did not improve from 0.95154
#
# Epoch 00824: val_acc did not improve from 0.95154
#
# Epoch 00825: val_acc did not improve from 0.95154
#
# Epoch 00826: val_acc did not improve from 0.95154
#
# Epoch 00827: val_acc did not improve from 0.95154
#
# Epoch 00828: val_acc did not improve from 0.95154
#
# Epoch 00829: val_acc did not improve from 0.95154
#
# Epoch 00830: val_acc did not improve from 0.95154
#
# Epoch 00831: val_acc did not improve from 0.95154
#
# Epoch 00832: val_acc did not improve from 0.95154
#
# Epoch 00833: val_acc did not improve from 0.95154
#
# Epoch 00834: val_acc did not improve from 0.95154
#
# Epoch 00835: val_acc did not improve from 0.95154
#
# Epoch 00836: val_acc did not improve from 0.95154
#
# Epoch 00837: val_acc did not improve from 0.95154
#
# Epoch 00838: val_acc did not improve from 0.95154
#
# Epoch 00839: val_acc did not improve from 0.95154
#
# Epoch 00840: val_acc did not improve from 0.95154
#
# Epoch 00841: val_acc did not improve from 0.95154
#
# Epoch 00842: val_acc did not improve from 0.95154
#
# Epoch 00843: val_acc did not improve from 0.95154
#
# Epoch 00844: val_acc did not improve from 0.95154
#
# Epoch 00845: val_acc did not improve from 0.95154
#
# Epoch 00846: val_acc did not improve from 0.95154
#
# Epoch 00847: val_acc did not improve from 0.95154
#
# Epoch 00848: val_acc did not improve from 0.95154
#
# Epoch 00849: val_acc did not improve from 0.95154
#
# Epoch 00850: val_acc did not improve from 0.95154
#
# Epoch 00851: val_acc did not improve from 0.95154
#
# Epoch 00852: val_acc did not improve from 0.95154
#
# Epoch 00853: val_acc did not improve from 0.95154
#
# Epoch 00854: val_acc did not improve from 0.95154
#
# Epoch 00855: val_acc did not improve from 0.95154
#
# Epoch 00856: val_acc did not improve from 0.95154
#
# Epoch 00857: val_acc did not improve from 0.95154
#
# Epoch 00858: val_acc did not improve from 0.95154
#
# Epoch 00859: val_acc did not improve from 0.95154
#
# Epoch 00860: val_acc did not improve from 0.95154
#
# Epoch 00861: val_acc did not improve from 0.95154
#
# Epoch 00862: val_acc did not improve from 0.95154
#
# Epoch 00863: val_acc did not improve from 0.95154
#
# Epoch 00864: val_acc did not improve from 0.95154
#
# Epoch 00865: val_acc did not improve from 0.95154
#
# Epoch 00866: val_acc did not improve from 0.95154
#
# Epoch 00867: val_acc did not improve from 0.95154
#
# Epoch 00868: val_acc did not improve from 0.95154
#
# Epoch 00869: val_acc did not improve from 0.95154
#
# Epoch 00870: val_acc did not improve from 0.95154
#
# Epoch 00871: val_acc did not improve from 0.95154
#
# Epoch 00872: val_acc did not improve from 0.95154
#
# Epoch 00873: val_acc did not improve from 0.95154
#
# Epoch 00874: val_acc did not improve from 0.95154
#
# Epoch 00875: val_acc did not improve from 0.95154
#
# Epoch 00876: val_acc did not improve from 0.95154
#
# Epoch 00877: val_acc did not improve from 0.95154
#
# Epoch 00878: val_acc did not improve from 0.95154
#
# Epoch 00879: val_acc did not improve from 0.95154
#
# Epoch 00880: val_acc did not improve from 0.95154
#
# Epoch 00881: val_acc did not improve from 0.95154
#
# Epoch 00882: val_acc did not improve from 0.95154
#
# Epoch 00883: val_acc did not improve from 0.95154
#
# Epoch 00884: val_acc did not improve from 0.95154
#
# Epoch 00885: val_acc did not improve from 0.95154
#
# Epoch 00886: val_acc did not improve from 0.95154
#
# Epoch 00887: val_acc did not improve from 0.95154
#
# Epoch 00888: val_acc did not improve from 0.95154
#
# Epoch 00889: val_acc did not improve from 0.95154
#
# Epoch 00890: val_acc did not improve from 0.95154
#
# Epoch 00891: val_acc did not improve from 0.95154
#
# Epoch 00892: val_acc did not improve from 0.95154
#
# Epoch 00893: val_acc did not improve from 0.95154
#
# Epoch 00894: val_acc did not improve from 0.95154
#
# Epoch 00895: val_acc did not improve from 0.95154
#
# Epoch 00896: val_acc did not improve from 0.95154
#
# Epoch 00897: val_acc did not improve from 0.95154
#
# Epoch 00898: val_acc did not improve from 0.95154
#
# Epoch 00899: val_acc did not improve from 0.95154
#
# Epoch 00900: val_acc did not improve from 0.95154
#
# Epoch 00901: val_acc did not improve from 0.95154
#
# Epoch 00902: val_acc did not improve from 0.95154
#
# Epoch 00903: val_acc did not improve from 0.95154
#
# Epoch 00904: val_acc did not improve from 0.95154
#
# Epoch 00905: val_acc did not improve from 0.95154
#
# Epoch 00906: val_acc did not improve from 0.95154
#
# Epoch 00907: val_acc did not improve from 0.95154
#
# Epoch 00908: val_acc did not improve from 0.95154
#
# Epoch 00909: val_acc did not improve from 0.95154
#
# Epoch 00910: val_acc did not improve from 0.95154
#
# Epoch 00911: val_acc did not improve from 0.95154
#
# Epoch 00912: val_acc did not improve from 0.95154
#
# Epoch 00913: val_acc did not improve from 0.95154
#
# Epoch 00914: val_acc did not improve from 0.95154
#
# Epoch 00915: val_acc did not improve from 0.95154
#
# Epoch 00916: val_acc did not improve from 0.95154
#
# Epoch 00917: val_acc did not improve from 0.95154
#
# Epoch 00918: val_acc did not improve from 0.95154
#
# Epoch 00919: val_acc did not improve from 0.95154
#
# Epoch 00920: val_acc did not improve from 0.95154
#
# Epoch 00921: val_acc did not improve from 0.95154
#
# Epoch 00922: val_acc did not improve from 0.95154
#
# Epoch 00923: val_acc did not improve from 0.95154
#
# Epoch 00924: val_acc did not improve from 0.95154
#
# Epoch 00925: val_acc did not improve from 0.95154
#
# Epoch 00926: val_acc did not improve from 0.95154
#
# Epoch 00927: val_acc did not improve from 0.95154
#
# Epoch 00928: val_acc did not improve from 0.95154
#
# Epoch 00929: val_acc did not improve from 0.95154
#
# Epoch 00930: val_acc did not improve from 0.95154
#
# Epoch 00931: val_acc did not improve from 0.95154
#
# Epoch 00932: val_acc did not improve from 0.95154
#
# Epoch 00933: val_acc did not improve from 0.95154
#
# Epoch 00934: val_acc did not improve from 0.95154
#
# Epoch 00935: val_acc did not improve from 0.95154
#
# Epoch 00936: val_acc did not improve from 0.95154
#
# Epoch 00937: val_acc did not improve from 0.95154
#
# Epoch 00938: val_acc did not improve from 0.95154
#
# Epoch 00939: val_acc did not improve from 0.95154
#
# Epoch 00940: val_acc did not improve from 0.95154
#
# ...
#
# Epoch 01188: val_acc did not improve from 0.95154
#
# Epoch 01189: val_acc did not improve from 0.95154
#
# Epoch 01190: val_acc did not improve from 0.95154
#
# Epoch 01191: val_acc did not improve from 0.95154
#
# Epoch 01192: val_acc did not improve from 0.95154
#
# Epoch 01193: val_acc did not improve from 0.95154
#
# Epoch 01194: val_acc did not improve from 0.95154
#
# Epoch 01195: val_acc did not improve from 0.95154
#
# Epoch 01196: val_acc did not improve from 0.95154
#
# Epoch 01197: val_acc did not improve from 0.95154
#
# Epoch 01198: val_acc did not improve from 0.95154
#
# Epoch 01199: val_acc did not improve from 0.95154
#
# Epoch 01200: val_acc did not improve from 0.95154
#
# Epoch 01201: val_acc did not improve from 0.95154
#
# Epoch 01202: val_acc did not improve from 0.95154
#
# Epoch 01203: val_acc did not improve from 0.95154
#
# Epoch 01204: val_acc did not improve from 0.95154
#
# Epoch 01205: val_acc did not improve from 0.95154
#
# Epoch 01206: val_acc did not improve from 0.95154
#
# Epoch 01207: val_acc did not improve from 0.95154
#
# Epoch 01208: val_acc did not improve from 0.95154
#
# Epoch 01209: val_acc did not improve from 0.95154
#
# Epoch 01210: val_acc did not improve from 0.95154
#
# Epoch 01211: val_acc did not improve from 0.95154
#
# Epoch 01212: val_acc did not improve from 0.95154
#
# Epoch 01213: val_acc did not improve from 0.95154
#
# Epoch 01214: val_acc did not improve from 0.95154
#
# Epoch 01215: val_acc did not improve from 0.95154
#
# Epoch 01216: val_acc did not improve from 0.95154
#
# Epoch 01217: val_acc did not improve from 0.95154
#
# Epoch 01218: val_acc did not improve from 0.95154
#
# Epoch 01219: val_acc did not improve from 0.95154
#
# Epoch 01220: val_acc did not improve from 0.95154
#
# Epoch 01221: val_acc did not improve from 0.95154
#
# Epoch 01222: val_acc did not improve from 0.95154
#
# Epoch 01223: val_acc did not improve from 0.95154
#
# Epoch 01224: val_acc did not improve from 0.95154
#
# Epoch 01225: val_acc did not improve from 0.95154
#
# Epoch 01226: val_acc did not improve from 0.95154
#
# Epoch 01227: val_acc did not improve from 0.95154
#
# Epoch 01228: val_acc did not improve from 0.95154
#
# Epoch 01229: val_acc did not improve from 0.95154
#
# Epoch 01230: val_acc did not improve from 0.95154
#
# Epoch 01231: val_acc did not improve from 0.95154
#
# Epoch 01232: val_acc did not improve from 0.95154
#
# Epoch 01233: val_acc did not improve from 0.95154
#
# Epoch 01234: val_acc did not improve from 0.95154
#
# Epoch 01235: val_acc did not improve from 0.95154
#
# Epoch 01236: val_acc did not improve from 0.95154
#
# Epoch 01237: val_acc did not improve from 0.95154
#
# Epoch 01238: val_acc did not improve from 0.95154
#
# Epoch 01239: val_acc did not improve from 0.95154
#
# Epoch 01240: val_acc did not improve from 0.95154
#
# Epoch 01241: val_acc did not improve from 0.95154
#
# Epoch 01242: val_acc did not improve from 0.95154
#
# Epoch 01243: val_acc did not improve from 0.95154
#
# Epoch 01244: val_acc did not improve from 0.95154
#
# Epoch 01245: val_acc did not improve from 0.95154
#
# Epoch 01246: val_acc did not improve from 0.95154
#
# Epoch 01247: val_acc did not improve from 0.95154
#
# Epoch 01248: val_acc did not improve from 0.95154
#
# Epoch 01249: val_acc did not improve from 0.95154
#
# Epoch 01250: val_acc did not improve from 0.95154
#
# Epoch 01251: val_acc did not improve from 0.95154
#
# Epoch 01252: val_acc did not improve from 0.95154
#
# Epoch 01253: val_acc did not improve from 0.95154
#
# Epoch 01254: val_acc did not improve from 0.95154
#
# Epoch 01255: val_acc did not improve from 0.95154
#
# Epoch 01256: val_acc did not improve from 0.95154
#
# Epoch 01257: val_acc did not improve from 0.95154
#
# Epoch 01258: val_acc did not improve from 0.95154
#
# Epoch 01259: val_acc did not improve from 0.95154
#
# Epoch 01260: val_acc did not improve from 0.95154
#
# Epoch 01261: val_acc did not improve from 0.95154
#
# Epoch 01262: val_acc did not improve from 0.95154
#
# Epoch 01263: val_acc did not improve from 0.95154
#
# Epoch 01264: val_acc did not improve from 0.95154
#
# Epoch 01265: val_acc did not improve from 0.95154
#
# Epoch 01266: val_acc did not improve from 0.95154
#
# Epoch 01267: val_acc did not improve from 0.95154
#
# Epoch 01268: val_acc did not improve from 0.95154
#
# Epoch 01269: val_acc did not improve from 0.95154
#
# Epoch 01270: val_acc did not improve from 0.95154
#
# Epoch 01271: val_acc did not improve from 0.95154
#
# Epoch 01272: val_acc did not improve from 0.95154
#
# Epoch 01273: val_acc did not improve from 0.95154
#
# Epoch 01274: val_acc did not improve from 0.95154
#
# Epoch 01275: val_acc did not improve from 0.95154
#
# Epoch 01276: val_acc did not improve from 0.95154
#
# Epoch 01277: val_acc did not improve from 0.95154
#
# Epoch 01278: val_acc did not improve from 0.95154
#
# Epoch 01279: val_acc did not improve from 0.95154
#
# Epoch 01280: val_acc did not improve from 0.95154
#
# Epoch 01281: val_acc did not improve from 0.95154
#
# Epoch 01282: val_acc did not improve from 0.95154
#
# Epoch 01283: val_acc did not improve from 0.95154
#
# Epoch 01284: val_acc did not improve from 0.95154
#
# Epoch 01285: val_acc did not improve from 0.95154
#
# Epoch 01286: val_acc did not improve from 0.95154
#
# Epoch 01287: val_acc did not improve from 0.95154
#
# Epoch 01288: val_acc did not improve from 0.95154
#
# Epoch 01289: val_acc did not improve from 0.95154
#
# Epoch 01290: val_acc did not improve from 0.95154
#
# Epoch 01291: val_acc did not improve from 0.95154
#
# Epoch 01292: val_acc did not improve from 0.95154
#
# Epoch 01293: val_acc did not improve from 0.95154
#
# Epoch 01294: val_acc did not improve from 0.95154
#
# Epoch 01295: val_acc did not improve from 0.95154
#
# Epoch 01296: val_acc did not improve from 0.95154
#
# Epoch 01297: val_acc did not improve from 0.95154
#
# Epoch 01298: val_acc did not improve from 0.95154
#
# Epoch 01299: val_acc did not improve from 0.95154
#
# Epoch 01300: val_acc did not improve from 0.95154
#
# Epoch 01301: val_acc did not improve from 0.95154
#
# Epoch 01302: val_acc did not improve from 0.95154
#
# Epoch 01303: val_acc did not improve from 0.95154
#
# Epoch 01304: val_acc did not improve from 0.95154
#
# Epoch 01305: val_acc did not improve from 0.95154
#
# Epoch 01306: val_acc did not improve from 0.95154
#
# Epoch 01307: val_acc did not improve from 0.95154
#
# Epoch 01308: val_acc did not improve from 0.95154
#
# Epoch 01309: val_acc did not improve from 0.95154
#
# Epoch 01310: val_acc did not improve from 0.95154
#
# Epoch 01311: val_acc did not improve from 0.95154
#
# Epoch 01312: val_acc did not improve from 0.95154
#
# Epoch 01313: val_acc did not improve from 0.95154
#
# Epoch 01314: val_acc did not improve from 0.95154
#
# Epoch 01315: val_acc did not improve from 0.95154
#
# Epoch 01316: val_acc did not improve from 0.95154
#
# Epoch 01317: val_acc did not improve from 0.95154
#
# Epoch 01318: val_acc did not improve from 0.95154
#
# Epoch 01319: val_acc did not improve from 0.95154
#
# Epoch 01320: val_acc did not improve from 0.95154
#
# Epoch 01321: val_acc did not improve from 0.95154
#
# Epoch 01322: val_acc did not improve from 0.95154
#
# Epoch 01323: val_acc did not improve from 0.95154
#
# Epoch 01324: val_acc did not improve from 0.95154
#
# Epoch 01325: val_acc did not improve from 0.95154
#
# Epoch 01326: val_acc did not improve from 0.95154
#
# Epoch 01327: val_acc did not improve from 0.95154
#
# Epoch 01328: val_acc did not improve from 0.95154
#
# Epoch 01329: val_acc did not improve from 0.95154
#
# Epoch 01330: val_acc did not improve from 0.95154
#
# Epoch 01331: val_acc did not improve from 0.95154
#
# Epoch 01332: val_acc did not improve from 0.95154
#
# Epoch 01333: val_acc did not improve from 0.95154
#
# Epoch 01334: val_acc did not improve from 0.95154
#
# Epoch 01335: val_acc did not improve from 0.95154
#
# Epoch 01336: val_acc did not improve from 0.95154
#
# Epoch 01337: val_acc did not improve from 0.95154
#
# Epoch 01338: val_acc did not improve from 0.95154
#
# Epoch 01339: val_acc did not improve from 0.95154
#
# Epoch 01340: val_acc did not improve from 0.95154
#
# Epoch 01341: val_acc did not improve from 0.95154
#
# Epoch 01342: val_acc did not improve from 0.95154
#
# Epoch 01343: val_acc did not improve from 0.95154
#
# Epoch 01344: val_acc did not improve from 0.95154
#
# Epoch 01345: val_acc did not improve from 0.95154
#
# Epoch 01346: val_acc did not improve from 0.95154
#
# Epoch 01347: val_acc did not improve from 0.95154
#
# Epoch 01348: val_acc did not improve from 0.95154
#
# Epoch 01349: val_acc did not improve from 0.95154
#
# Epoch 01350: val_acc did not improve from 0.95154
#
# Epoch 01351: val_acc did not improve from 0.95154
#
# Epoch 01352: val_acc did not improve from 0.95154
#
# Epoch 01353: val_acc did not improve from 0.95154
#
# Epoch 01354: val_acc did not improve from 0.95154
#
# Epoch 01355: val_acc did not improve from 0.95154
#
# Epoch 01356: val_acc did not improve from 0.95154
#
# Epoch 01357: val_acc did not improve from 0.95154
#
# Epoch 01358: val_acc did not improve from 0.95154
#
# Epoch 01359: val_acc did not improve from 0.95154
#
# Epoch 01360: val_acc did not improve from 0.95154
#
# Epoch 01361: val_acc did not improve from 0.95154
#
# Epoch 01362: val_acc did not improve from 0.95154
#
# Epoch 01363: val_acc did not improve from 0.95154
#
# Epoch 01364: val_acc did not improve from 0.95154
#
# Epoch 01365: val_acc did not improve from 0.95154
#
# Epoch 01366: val_acc did not improve from 0.95154
#
# Epoch 01367: val_acc did not improve from 0.95154
#
# Epoch 01368: val_acc did not improve from 0.95154
#
# Epoch 01369: val_acc did not improve from 0.95154
#
# Epoch 01370: val_acc did not improve from 0.95154
#
# Epoch 01371: val_acc did not improve from 0.95154
#
# Epoch 01372: val_acc did not improve from 0.95154
#
# Epoch 01373: val_acc did not improve from 0.95154
#
# Epoch 01374: val_acc did not improve from 0.95154
#
# Epoch 01375: val_acc did not improve from 0.95154
#
# Epoch 01376: val_acc did not improve from 0.95154
#
# Epoch 01377: val_acc did not improve from 0.95154
#
# Epoch 01378: val_acc did not improve from 0.95154
#
# Epoch 01379: val_acc did not improve from 0.95154
#
# Epoch 01380: val_acc did not improve from 0.95154
#
# Epoch 01381: val_acc did not improve from 0.95154
#
# Epoch 01382: val_acc did not improve from 0.95154
#
# Epoch 01383: val_acc did not improve from 0.95154
#
# Epoch 01384: val_acc did not improve from 0.95154
#
# Epoch 01385: val_acc did not improve from 0.95154
#
# Epoch 01386: val_acc did not improve from 0.95154
#
# Epoch 01387: val_acc did not improve from 0.95154
#
# Epoch 01388: val_acc did not improve from 0.95154
#
# Epoch 01389: val_acc did not improve from 0.95154
#
# Epoch 01390: val_acc did not improve from 0.95154
#
# Epoch 01391: val_acc did not improve from 0.95154
#
# Epoch 01392: val_acc did not improve from 0.95154
#
# Epoch 01393: val_acc did not improve from 0.95154
#
# Epoch 01394: val_acc did not improve from 0.95154
#
# Epoch 01395: val_acc did not improve from 0.95154
#
# Epoch 01396: val_acc did not improve from 0.95154
#
# Epoch 01397: val_acc did not improve from 0.95154
#
# Epoch 01398: val_acc did not improve from 0.95154
#
# Epoch 01399: val_acc did not improve from 0.95154
#
# Epoch 01400: val_acc did not improve from 0.95154
#
# Epoch 01401: val_acc did not improve from 0.95154
#
# Epoch 01402: val_acc did not improve from 0.95154
#
# Epoch 01403: val_acc did not improve from 0.95154
#
# Epoch 01404: val_acc did not improve from 0.95154
#
# Epoch 01405: val_acc did not improve from 0.95154
#
# Epoch 01406: val_acc did not improve from 0.95154
#
# Epoch 01407: val_acc did not improve from 0.95154
#
# Epoch 01408: val_acc did not improve from 0.95154
#
# Epoch 01409: val_acc did not improve from 0.95154
#
# Epoch 01410: val_acc did not improve from 0.95154
#
# Epoch 01411: val_acc did not improve from 0.95154
#
# Epoch 01412: val_acc did not improve from 0.95154
#
# Epoch 01413: val_acc did not improve from 0.95154
#
# Epoch 01414: val_acc did not improve from 0.95154
#
# Epoch 01415: val_acc did not improve from 0.95154
#
# Epoch 01416: val_acc did not improve from 0.95154
#
# Epoch 01417: val_acc did not improve from 0.95154
#
# Epoch 01418: val_acc did not improve from 0.95154
#
# Epoch 01419: val_acc did not improve from 0.95154
#
# Epoch 01420: val_acc did not improve from 0.95154
#
# Epoch 01421: val_acc did not improve from 0.95154
#
# Epoch 01422: val_acc did not improve from 0.95154
#
# Epoch 01423: val_acc did not improve from 0.95154
#
# Epoch 01424: val_acc did not improve from 0.95154
#
# Epoch 01425: val_acc did not improve from 0.95154
#
# Epoch 01426: val_acc did not improve from 0.95154
#
# Epoch 01427: val_acc did not improve from 0.95154
#
# Epoch 01428: val_acc did not improve from 0.95154
#
# Epoch 01429: val_acc did not improve from 0.95154
#
# Epoch 01430: val_acc did not improve from 0.95154
#
# Epoch 01431: val_acc did not improve from 0.95154
#
# Epoch 01432: val_acc did not improve from 0.95154
#
# Epoch 01433: val_acc did not improve from 0.95154
#
# Epoch 01434: val_acc did not improve from 0.95154
#
# Epoch 01435: val_acc did not improve from 0.95154
#
# Epoch 01436: val_acc did not improve from 0.95154
#
# Epoch 01437: val_acc did not improve from 0.95154
#
# Epoch 01438: val_acc did not improve from 0.95154
#
# Epoch 01439: val_acc did not improve from 0.95154
#
# Epoch 01440: val_acc did not improve from 0.95154
#
# Epoch 01441: val_acc did not improve from 0.95154
#
# Epoch 01442: val_acc did not improve from 0.95154
#
# Epoch 01443: val_acc did not improve from 0.95154
#
# Epoch 01444: val_acc did not improve from 0.95154
#
# Epoch 01445: val_acc did not improve from 0.95154
#
# Epoch 01446: val_acc did not improve from 0.95154
#
# Epoch 01447: val_acc did not improve from 0.95154
#
# Epoch 01448: val_acc did not improve from 0.95154
#
# Epoch 01449: val_acc did not improve from 0.95154
#
# Epoch 01450: val_acc did not improve from 0.95154
#
# Epoch 01451: val_acc did not improve from 0.95154
#
# Epoch 01452: val_acc did not improve from 0.95154
#
# Epoch 01453: val_acc did not improve from 0.95154
#
# Epoch 01454: val_acc did not improve from 0.95154
#
# Epoch 01455: val_acc did not improve from 0.95154
#
# Epoch 01456: val_acc did not improve from 0.95154
#
# Epoch 01457: val_acc did not improve from 0.95154
#
# Epoch 01458: val_acc did not improve from 0.95154
#
# Epoch 01459: val_acc did not improve from 0.95154
#
# Epoch 01460: val_acc did not improve from 0.95154
#
# Epoch 01461: val_acc did not improve from 0.95154
#
# Epoch 01462: val_acc did not improve from 0.95154
#
# Epoch 01463: val_acc did not improve from 0.95154
#
# Epoch 01464: val_acc did not improve from 0.95154
#
# Epoch 01465: val_acc did not improve from 0.95154
#
# Epoch 01466: val_acc did not improve from 0.95154
#
# Epoch 01467: val_acc did not improve from 0.95154
#
# Epoch 01468: val_acc did not improve from 0.95154
#
# Epoch 01469: val_acc did not improve from 0.95154
#
# Epoch 01470: val_acc did not improve from 0.95154
#
# Epoch 01471: val_acc did not improve from 0.95154
#
# Epoch 01472: val_acc did not improve from 0.95154
#
# Epoch 01473: val_acc did not improve from 0.95154
#
# Epoch 01474: val_acc did not improve from 0.95154
#
# Epoch 01475: val_acc did not improve from 0.95154
#
# Epoch 01476: val_acc did not improve from 0.95154
#
# Epoch 01477: val_acc did not improve from 0.95154
#
# Epoch 01478: val_acc did not improve from 0.95154
#
# Epoch 01479: val_acc did not improve from 0.95154
#
# Epoch 01480: val_acc did not improve from 0.95154
#
# Epoch 01481: val_acc did not improve from 0.95154
#
# Epoch 01482: val_acc did not improve from 0.95154
#
# Epoch 01483: val_acc did not improve from 0.95154
#
# Epoch 01484: val_acc did not improve from 0.95154
#
# Epoch 01485: val_acc did not improve from 0.95154
#
# Epoch 01486: val_acc did not improve from 0.95154
#
# Epoch 01487: val_acc did not improve from 0.95154
#
# Epoch 01488: val_acc did not improve from 0.95154
#
# Epoch 01489: val_acc did not improve from 0.95154
#
# Epoch 01490: val_acc did not improve from 0.95154
#
# Epoch 01491: val_acc did not improve from 0.95154
#
# Epoch 01492: val_acc did not improve from 0.95154
#
# Epoch 01493: val_acc did not improve from 0.95154
#
# Epoch 01494: val_acc did not improve from 0.95154
#
# Epoch 01495: val_acc did not improve from 0.95154
#
# Epoch 01496: val_acc did not improve from 0.95154
#
# Epoch 01497: val_acc did not improve from 0.95154
#
# Epoch 01498: val_acc did not improve from 0.95154
#
# Epoch 01499: val_acc did not improve from 0.95154
#
# Epoch 01500: val_acc did not improve from 0.95154

# %%
# model3.save('ML_task2.h5')

# %%
# model3 = load_model('weights.best.hdf5',custom_objects={'f1_m':f1_m,'precision_m':precision_m,'recall_m':recall_m})
model3 = load_model('weights_with_normalize.best.hdf5',custom_objects={'f1_m':f1_m,'precision_m':precision_m,'recall_m':recall_m})

# %%
print('\nTesting ------------')
loss, accuracy, f1_score, precision, recall = model3.evaluate(val_x, val_y, verbose=0)
print('\ntest loss: ', loss)
print('\ntest f1_score: ', f1_score) #no normal best 0.9746232628822327
# Out:
# Testing ------------
#
# test loss:  0.141359344124794
#
# test f1_score:  0.9531777501106262

# %%
test.shape
# Out:
# (2000, 23)

# %%
# for i in range(np.shape(test)[1]):
#     mean = meanlist[i]
#     std  = stdlist[i]
#     for j in range(np.shape(test)[0]):
#         test[j][i] = (test[j][i]-mean)/std

# %%
np.sum(test[:,1])
# Out:
# 20549.914

# %%
prediction = model3.predict(test)

# %%
np.argmax(prediction[0], axis=0)
# Out:
# 0

# %%
alph = ['A','B','C','D','E','F','G','H','I','J']

# %%
prediction_final=[]

# %%
for i in range(np.shape(prediction)[0]):
    index = np.argmax(prediction[i], axis=0)
    prediction_final.append(alph[index])

# %%
prediction_final
# Out:
# ['A',
#  'G',
#  'C',
#  'H',
#  'D',
#  'H',
#  'C',
#  'H',
#  'B',
#  'D',
#  'D',
#  'F',
#  'J',
#  'E',
#  'F',
#  'G',
#  'C',
#  'C',
#  'J',
#  'G',
#  'F',
#  'E',
#  'C',
#  'I',
#  'H',
#  'B',
#  'E',
#  'F',
#  'H',
#  'G',
#  'H',
#  'A',
#  'H',
#  'J',
#  'E',
#  'A',
#  'J',
#  'G',
#  'C',
#  'F',
#  'B',
#  'J',
#  'F',
#  'J',
#  'E',
#  'D',
#  'F',
#  'B',
#  'I',
#  'C',
#  'C',
#  'E',
#  'A',
#  'A',
#  'H',
#  'G',
#  'H',
#  'D',
#  'A',
#  'I',
#  'C',
#  'B',
#  'J',
#  'J',
#  'C',
#  'I',
#  'J',
#  'J',
#  'A',
#  'G',
#  'H',
#  'E',
#  'B',
#  'H',
#  'A',
#  'H',
#  'E',
#  'E',
#  'A',
#  'E',
#  'I',
#  'G',
#  'C',
#  'H',
#  'E',
#  'H',
#  'J',
#  'E',
#  'F',
#  'D',
#  'A',
#  'C',
#  'D',
#  'F',
#  'B',
#  'J',
#  'F',
#  'F',
#  'I',
#  'A',
#  'C',
#  'F',
#  'G',
#  'C',
#  'J',
#  'J',
#  'A',
#  'F',
#  'C',
#  'I',
#  'J',
#  'E',
#  'H',
#  'J',
#  'E',
#  'C',
#  'C',
#  'B',
#  'H',
#  'D',
#  'E',
#  'E',
#  'H',
#  'I',
#  'G',
#  'A',
#  'B',
#  'A',
#  'D',
#  'H',
#  'C',
#  'D',
#  'I',
#  'I',
#  'B',
#  'I',
#  'C',
#  'G',
#  'B',
#  'I',
#  'D',
#  'F',
#  'B',
#  'E',
#  'F',
#  'A',
#  'C',
#  'J',
#  'H',
#  'B',
#  'A',
#  'A',
#  'F',
#  'J',
#  'B',
#  'E',
#  'I',
#  'B',
#  'J',
#  'C',
#  'F',
#  'D',
#  'I',
#  'C',
#  'A',
#  'F',
#  'C',
#  'C',
#  'C',
#  'H',
#  'H',
#  'G',
#  'C',
#  'C',
#  'H',
#  'C',
#  'H',
#  'D',
#  'F',
#  'E',
#  'G',
#  'B',
#  'D',
#  'E',
#  'C',
#  'I',
#  'B',
#  'G',
#  'A',
#  'A',
#  'G',
#  'C',
#  'A',
#  'B',
#  'A',
#  'C',
#  'I',
#  'C',
#  'G',
#  'I',
#  'C',
#  'G',
#  'F',
#  'J',
#  'I',
#  'C',
#  'J',
#  'I',
#  'F',
#  'H',
#  'A',
#  'I',
#  'D',
#  'A',
#  'J',
#  'B',
#  'D',
#  'G',
#  'E',
#  'D',
#  'J',
#  'J',
#  'H',
#  'H',
#  'G',
#  'J',
#  'C',
#  'I',
#  'J',
#  'A',
#  'J',
#  'B',
#  'D',
#  'F',
#  'B',
#  'J',
#  'G',
#  'G',
#  'B',
#  'J',
#  'D',
#  'D',
#  'A',
#  'A',
#  'A',
#  'E',
#  'F',
#  'E',
#  'I',
#  'I',
#  'D',
#  'B',
#  'B',
#  'J',
#  'D',
#  'H',
#  'A',
#  'H',
#  'I',
#  'E',
#  'E',
#  'A',
#  'D',
#  'J',
#  'A',
#  'H',
#  'E',
#  'D',
#  'G',
#  'H',
#  'D',
#  'E',
#  'J',
#  'E',
#  'C',
#  'J',
#  'D',
#  'I',
#  'C',
#  'I',
#  'H',
#  'J',
#  'C',
#  'C',
#  'D',
#  'F',
#  'F',
#  'G',
#  'J',
#  'D',
#  'F',
#  'F',
#  'H',
#  'F',
#  'B',
#  'J',
#  'D',
#  'E',
#  'C',
#  'A',
#  'I',
#  'H',
#  'I',
#  'F',
#  'I',
#  'I',
#  'D',
#  'I',
#  'F',
#  'A',
#  'D',
#  'A',
#  'C',
#  'A',
#  'F',
#  'F',
#  'B',
#  'I',
#  'F',
#  'G',
#  'E',
#  'C',
#  'J',
#  'C',
#  'C',
#  'D',
#  'F',
#  'F',
#  'J',
#  'A',
#  'H',
#  'G',
#  'E',
#  'I',
#  'G',
#  'F',
#  'A',
#  'E',
#  'A',
#  'C',
#  'E',
#  'A',
#  'G',
#  'A',
#  'B',
#  'G',
#  'I',
#  'J',
#  'B',
#  'G',
#  'F',
#  'E',
#  'I',
#  'E',
#  'J',
#  'H',
#  'B',
#  'E',
#  'I',
#  'A',
#  'I',
#  'G',
#  'F',
#  'G',
#  'G',
#  'E',
#  'H',
#  'A',
#  'A',
#  'D',
#  'C',
#  'J',
#  'G',
#  'C',
#  'G',
#  'G',
#  'I',
#  'E',
#  'G',
#  'J',
#  'J',
#  'F',
#  'D',
#  'B',
#  'D',
#  'G',
#  'I',
#  'B',
#  'E',
#  'H',
#  'A',
#  'B',
#  'J',
#  'C',
#  'A',
#  'D',
#  'B',
#  'I',
#  'D',
#  'D',
#  'H',
#  'D',
#  'F',
#  'H',
#  'J',
#  'A',
#  'G',
#  'H',
#  'C',
#  'B',
#  'B',
#  'B',
#  'C',
#  'E',
#  'C',
#  'B',
#  'A',
#  'J',
#  'G',
#  'H',
#  'H',
#  'I',
#  'J',
#  'E',
#  'H',
#  'I',
#  'D',
#  'F',
#  'D',
#  'I',
#  'J',
#  'F',
#  'F',
#  'F',
#  'A',
#  'H',
#  'G',
#  'B',
#  'D',
#  'D',
#  'H',
#  'A',
#  'G',
#  'C',
#  'E',
#  'H',
#  'A',
#  'F',
#  'F',
#  'F',
#  'E',
#  'I',
#  'I',
#  'A',
#  'E',
#  'H',
#  'J',
#  'C',
#  'I',
#  'D',
#  'G',
#  'A',
#  'F',
#  'G',
#  'F',
#  'E',
#  'H',
#  'F',
#  'D',
#  'F',
#  'A',
#  'B',
#  'E',
#  'H',
#  'J',
#  'F',
#  'C',
#  'G',
#  'F',
#  'E',
#  'J',
#  'J',
#  'H',
#  'B',
#  'H',
#  'A',
#  'B',
#  'B',
#  'A',
#  'E',
#  'A',
#  'C',
#  'F',
#  'E',
#  'A',
#  'C',
#  'H',
#  'I',
#  'C',
#  'H',
#  'D',
#  'F',
#  'F',
#  'H',
#  'H',
#  'E',
#  'D',
#  'I',
#  'G',
#  'D',
#  'I',
#  'C',
#  'C',
#  'J',
#  'I',
#  'G',
#  'G',
#  'E',
#  'D',
#  'F',
#  'D',
#  'I',
#  'E',
#  'I',
#  'H',
#  'H',
#  'F',
#  'D',
#  'I',
#  'A',
#  'C',
#  'I',
#  'I',
#  'E',
#  'G',
#  'C',
#  'F',
#  'I',
#  'B',
#  'H',
#  'I',
#  'D',
#  'B',
#  'B',
#  'C',
#  'E',
#  'B',
#  'D',
#  'H',
#  'H',
#  'B',
#  'C',
#  'C',
#  'J',
#  'G',
#  'B',
#  'I',
#  'D',
#  'D',
#  'D',
#  'A',
#  'B',
#  'F',
#  'J',
#  'A',
#  'H',
#  'B',
#  'A',
#  'I',
#  'E',
#  'B',
#  'H',
#  'H',
#  'B',
#  'D',
#  'D',
#  'B',
#  'B',
#  'J',
#  'G',
#  'G',
#  'I',
#  'C',
#  'I',
#  'I',
#  'I',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'F',
#  'E',
#  'G',
#  'F',
#  'F',
#  'G',
#  'F',
#  'E',
#  'C',
#  'A',
#  'D',
#  'A',
#  'C',
#  'B',
#  'J',
#  'I',
#  'I',
#  'E',
#  'A',
#  'B',
#  'B',
#  'G',
#  'A',
#  'J',
#  'D',
#  'I',
#  'D',
#  'J',
#  'J',
#  'F',
#  'H',
#  'C',
#  'B',
#  'E',
#  'G',
#  'D',
#  'B',
#  'E',
#  'B',
#  'J',
#  'D',
#  'F',
#  'A',
#  'E',
#  'F',
#  'F',
#  'D',
#  'D',
#  'A',
#  'B',
#  'B',
#  'J',
#  'B',
#  'I',
#  'H',
#  'D',
#  'J',
#  'E',
#  'D',
#  'A',
#  'I',
#  'I',
#  'B',
#  'A',
#  'A',
#  'E',
#  'D',
#  'A',
#  'H',
#  'A',
#  'B',
#  'B',
#  'E',
#  'H',
#  'C',
#  'I',
#  'G',
#  'J',
#  'G',
#  'D',
#  'J',
#  'E',
#  'A',
#  'A',
#  'G',
#  'F',
#  'J',
#  'D',
#  'G',
#  'A',
#  'J',
#  'C',
#  'H',
#  'A',
#  'J',
#  'J',
#  'C',
#  'G',
#  'H',
#  'A',
#  'C',
#  'F',
#  'A',
#  'E',
#  'F',
#  'A',
#  'I',
#  'A',
#  'I',
#  'H',
#  'H',
#  'G',
#  'F',
#  'A',
#  'B',
#  'A',
#  'E',
#  'B',
#  'D',
#  'I',
#  'E',
#  'H',
#  'H',
#  'J',
#  'D',
#  'B',
#  'A',
#  'I',
#  'C',
#  'J',
#  'J',
#  'F',
#  'D',
#  'G',
#  'D',
#  'D',
#  'I',
#  'F',
#  'H',
#  'B',
#  'B',
#  'F',
#  'D',
#  'H',
#  'I',
#  'D',
#  'F',
#  'H',
#  'C',
#  'J',
#  'I',
#  'D',
#  'G',
#  'C',
#  'F',
#  'C',
#  'I',
#  'D',
#  'F',
#  'D',
#  'G',
#  'J',
#  'A',
#  'C',
#  'J',
#  'J',
#  'C',
#  'C',
#  'I',
#  'A',
#  'G',
#  'A',
#  'I',
#  'D',
#  'C',
#  'D',
#  'D',
#  'B',
#  'A',
#  'A',
#  'E',
#  'D',
#  'D',
#  'H',
#  'J',
#  'I',
#  'I',
#  'A',
#  'B',
#  'C',
#  'B',
#  'E',
#  'G',
#  'A',
#  'D',
#  'D',
#  'B',
#  'C',
#  'A',
#  'J',
#  'E',
#  'C',
#  'B',
#  'J',
#  'E',
#  'B',
#  'B',
#  'F',
#  'H',
#  'F',
#  'H',
#  'I',
#  'J',
#  'H',
#  'A',
#  'I',
#  'H',
#  'G',
#  'J',
#  'E',
#  'I',
#  'D',
#  'A',
#  'E',
#  'E',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'H',
#  'B',
#  'I',
#  'G',
#  'D',
#  'D',
#  'C',
#  'H',
#  'I',
#  'J',
#  'I',
#  'J',
#  'D',
#  'B',
#  'H',
#  'E',
#  'A',
#  'C',
#  'A',
#  'C',
#  'A',
#  'A',
#  'A',
#  'G',
#  'H',
#  'E',
#  'J',
#  'B',
#  'J',
#  'E',
#  'E',
#  'E',
#  'D',
#  'I',
#  'J',
#  'D',
#  'A',
#  'B',
#  'G',
#  'I',
#  'G',
#  'E',
#  'H',
#  'E',
#  'C',
#  'I',
#  'H',
#  'E',
#  'C',
#  'B',
#  'F',
#  'B',
#  'B',
#  'B',
#  'D',
#  'A',
#  'A',
#  'F',
#  'D',
#  'C',
#  'A',
#  'F',
#  'E',
#  'G',
#  'H',
#  'I',
#  'C',
#  'B',
#  'J',
#  'E',
#  'E',
#  'J',
#  'J',
#  'E',
#  'F',
#  'F',
#  'B',
#  'B',
#  'G',
#  'G',
#  'C',
#  'B',
#  'H',
#  'H',
#  'B',
#  'E',
#  'G',
#  'B',
#  'F',
#  'G',
#  'A',
#  'D',
#  'E',
#  'I',
#  'J',
#  'I',
#  'G',
#  'A',
#  'A',
#  'D',
#  'G',
#  'H',
#  'H',
#  'J',
#  'G',
#  'B',
#  'J',
#  'C',
#  'H',
#  'E',
#  'D',
#  'A',
#  'C',
#  'D',
#  'A',
#  'I',
#  'F',
#  'E',
#  'H',
#  'E',
#  'B',
#  'C',
#  'J',
#  'C',
#  'J',
#  'A',
#  'D',
#  'C',
#  'C',
#  'A',
#  'E',
#  'D',
#  'C',
#  'B',
#  'C',
#  'F',
#  'B',
#  'D',
#  'E',
#  'A',
#  'A',
#  'F',
#  'D',
#  'C',
#  'A',
#  'J',
#  'E',
#  'F',
#  'I',
#  'H',
#  'E',
#  'E',
#  'B',
#  'G',
#  'C',
#  'F',
#  'C',
#  'D',
#  'I',
#  'D',
#  'D',
#  'D',
#  'G',
#  'G',
#  'C',
#  'B',
#  'C',
#  'D',
#  'E',
#  'D',
#  'F',
#  'A',
#  'F',
#  'A',
#  'J',
#  'G',
#  'F',
#  'I',
#  'J',
#  ...]

# %%
tt = dict([('id',np.array(range(1,2001))),('Predicted',prediction_final)])

# %%
tt = pd.DataFrame(tt)

# %%
tt.to_csv('test.csv',index=False)
